# %%
import pandas as pd

# %%
courses = pd.read_csv("courses.csv")
courses
# registration.csv
# role.csv
# staff.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /Users/maarunipandithurai/Documents/GitHub/SPM_T4/sth.ipynb Cell 2 in <module>
# ----> <a href='vscode-notebook-cell:/Users/maarunipandithurai/Documents/GitHub/SPM_T4/sth.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> courses = pd.read_csv("courses.csv")
#       <a href='vscode-notebook-cell:/Users/maarunipandithurai/Documents/GitHub/SPM_T4/sth.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> courses
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1231, in TextFileReader._make_engine(self, f, engine)
#    1228     f = self.handles.handle
#    1230 try:
# -> 1231     return mapping[engine](f, **self.options)
#    1232 except Exception:
#    1233     if self.handles is not None:
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 2453: invalid start byte

# %%
registration = pd.read_csv("registration.csv")
registration
# Out:
#      Reg_ID Course_ID  Staff_ID  Reg_Status Completion_Status
# 0         1    COR002    130001  Registered         Completed
# 1       245    COR001    130001  Registered         Completed
# 2         2    COR002    130002  Registered         Completed
# 3         3    COR002    140001  Registered         Completed
# 4       111    SAL004    140001  Registered         Completed
# ..      ...       ...       ...         ...               ...
# 374     369    FIN003    160258  Registered               NaN
# 375     108    COR002    160282    Waitlist               NaN
# 376     188    MGT001    160282    Waitlist               NaN
# 377     236    tch002    160282  Registered         Completed
# 378     370    HRD001    160282    Waitlist               NaN
#
# [379 rows x 5 columns]

# %%
role = pd.read_csv("role.csv")
role
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /Users/maarunipandithurai/Documents/GitHub/SPM_T4/sth.ipynb Cell 4 in <module>
# ----> <a href='vscode-notebook-cell:/Users/maarunipandithurai/Documents/GitHub/SPM_T4/sth.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> role = pd.read_csv("role.csv")
#       <a href='vscode-notebook-cell:/Users/maarunipandithurai/Documents/GitHub/SPM_T4/sth.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> role
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1250, in TextFileReader.read(self, nrows)
#    1248 nrows = validate_integer("nrows", nrows)
#    1249 try:
# -> 1250     index, columns, col_dict = self._engine.read(nrows)
#    1251 except Exception:
#    1252     self.close()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/.pyenv/versions/venv/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 3, saw 3

# %%
staff = pd.read_csv("staff.csv")
staff
# Out:
#      Staff_ID Staff_FName Staff_LName      Dept                         Email  \
# 0      130001        John         Sim  Chariman      jack.sim@allinone.com.sg
# 1      130002        Jack         Sim       CEO      jack.sim@allinone.com.sg
# 2      140001       Derek         Tan     Sales     Derek.Tan@allinone.com.sg
# 3      140002       Susan         Goh     Sales     Susan.Goh@allinone.com.sg
# 4      140003      Janice        Chan     Sales   Janice.Chan@allinone.com.sg
# ..        ...         ...         ...       ...                           ...
# 138    170238     Jackson        Chan   Finance  Jackson.Chan@allinone.com.sg
# 139    170245       Aiden         Teo   Finance     Aiden.Teo@allinone.com.sg
# 140    170655      Samuel         Lee   Finance    Samuel.Lee@allinone.com.sg
# 141    170866       Susan         Lim   Finance     Susan.Lim@allinone.com.sg
# 142    171008      Janice        Heng   Finance   Janice.Heng@allinone.com.sg
#
#      Role
# 0       1
# 1       1
# 2       3
# 3       2
# 4       2
# ..    ...
# 138     2
# 139     2
# 140     2
# 141     2
# 142     2
#
# [143 rows x 6 columns]
